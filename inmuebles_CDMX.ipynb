# %% [markdown]
# <a href="https://colab.research.google.com/github/Eve113/AnalisisDeDatosEPR1/blob/main/inmuebles_CDMX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %% [markdown]
# ## **Importando la base de datos**

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

pd.read_csv(url, sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep=';')

# %%
# Primeras 5 filas
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
# Ultimás 5 filas
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
# Muestra aleatoria
datos.sample(5)
# Out:
#                Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 13171  Departamento          Santa Fe             2        1       0    66
# 14388      Cocineta  Centro Histórico             0        0       0    26
# 748    Departamento          Santa Fe             4        3       2   270
# 6920   Departamento           Condesa             4        3       2   430
# 358            Casa            Juárez            10        0      10   300
#
#          Valor  Condominio  Impuesto
# 13171  10500.0      5425.0    1330.0
# 14388   2450.0      2555.0     420.0
# 748    24500.0      9100.0    2275.0
# 6920   35000.0      9922.5    5411.0
# 358    52500.0         NaN     770.0

# %%
# tipo de datos
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Formato de datos**
#
#
#
# *   read_csv(): Esta función se utiliza para leer archivos CSV
# *   read_excel(): Esta función se utiliza para leer archivos de Excel (.xls o .xlsx) y crear un DataFrame a partir de los datos.
# *   read_json(): Esta función se utiliza para leer archivos JSON
# *   read_html(): Esta función se utiliza para leer tablas HTML, que son estructuras de datos organizadas en formato de tabla en una página web.
# *   read_sql(): Esta función se utiliza para leer datos de una base de datos relacional, como MySQL, PostgreSQL y SQL Server

# %% [markdown]
# ## Exploración de los datos

# %%
datos.head(5)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
# numero de filas y columnas
datos.shape
# Out:
# (25121, 9)

# %%
# columnas
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
# informacion de la data base
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Habitaciones','Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# ### **DEMANDAS ML**

# %% [markdown]
# ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
datos['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
datos.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh', figsize=(12,8), color = 'purple')
# Out:
# <Axes: ylabel='Tipo'>

# %%
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo','Tienda/Salón',
                         'Casa Comercial','Terreno Estándar', 'Cochera/Estacionamiento',
                         'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial',
                         'Hotel', 'Loteo/Condominio','Industria']

# %%
datos.query('@inmuebles_comerciales in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
datos.query('@inmuebles_comerciales not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = datos.query('@inmuebles_comerciales not in Tipo')
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
df_tipo_precio = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh', figsize=(12,8), color = 'purple')
# Out:
# <Axes: ylabel='Tipo'>

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
# Porcentajes

df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
df_nuevo = df.query('Tipo == "Departamento"')
df_nuevo.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 7   Departamento  Centro Histórico             1        0       0    36
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       NaN
# 7    4200.0         NaN       NaN
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5

# %%
porcentaje_tipo = df.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind='bar', figsize=(12,8), color = 'purple', xlabel = 'Tipos', ylabel = 'Porcentaje')
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentaje'>

# %%
df_nuevo.shape
# Out:
# (14764, 9)

# %%
df_nuevo.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
df_nuevo.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
df_nuevo= df_nuevo.fillna(0)

# %%
df_nuevo.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %%
df_nuevo.drop('Tipo',axis=1,inplace=True)

# %% [markdown]
# ### **Remover datos inconsistentes**

# %%
df_nuevo.query('Valor == 0 | Condominio == 0')
# Out:
#                       Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 7            Centro Histórico             1        0       0    36   4200.0
# 49                   Santa Fe             2        1       1    70      0.0
# 74     Ciudad de los Deportes             2        0       0    80   3500.0
# 116                El Rosedal             2        1       0    50   3850.0
# 136                  Santa Fe             1        1       1    65   8225.0
# ...                       ...           ...      ...     ...   ...      ...
# 24721                Doctores             2        0       0    43   3150.0
# 24736                 Condesa             1        0       0    30   9100.0
# 24866                 Condesa             3        0       0   130  16100.0
# 24892             Loma Bonita             1        0       0    40   1925.0
# 25014           Culhuacán CTM             3        0       1    70   4200.0
#
#        Condominio  Impuesto
# ...

# %%
df_nuevo.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
df_remover = df_nuevo.query('Valor == 0 | Condominio == 0').index

# %%
df_nuevo.drop(df_remover,axis=0,inplace=True)

# %%
df_nuevo.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([], dtype='int64')

# %% [markdown]
# ## Creando Filtros

# %% [markdown]
# 1.   Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200

# %%
select1 = df_nuevo['Habitaciones']==1

# %%
type(select1)
# Out:
# pandas.core.series.Series

# %%
df_nuevo[select1]
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# 37         Centro Histórico             1        0       0    27   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
select2 = df_nuevo['Valor']<4200

# %%
df_nuevo[select2].max()
# Out:
# Colonia         Álvaro Obregón
# Habitaciones                 3
# Garages                      2
# Suites                       2
# Area                       176
# Valor                   4025.0
# Condominio            152575.5
# Impuesto                6699.0
# dtype: object

# %%
filtro1 = (select1) & (select2)
df_nuevo[filtro1]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
df1 = df_nuevo[filtro1]

# %% [markdown]
# 2.   Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70m^2

# %%
filtro2 = (df_nuevo['Habitaciones'] >= 2) & (df_nuevo['Valor'] < 10500) & (df_nuevo['Area'] > 70)

# %%
df_nuevo[filtro2]
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %%
df2 = df_nuevo[filtro2]

# %% [markdown]
# 3.   ¿Cuáles son los apartamentos que tienen un área mayor de 80 m² o un alquiler menor de MXN 4.000,00?

# %%
filtro3 = (df_nuevo['Area'] > 80) | (df_nuevo['Valor'] < 4000)
df3 = df_nuevo[filtro3]
df_nuevo[filtro3]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3      Centro Histórico             1        0       0    15   2800.0
# 4             Del Valle             1        0       0    48   2800.0
# 10              Condesa             4        3       1   243  45500.0
# 14             Narvarte             2        1       0   110   6650.0
# 18             Coyoacán             3        1       1   125  24500.0
# ...                 ...           ...      ...     ...   ...      ...
# 25105          Santa Fe             2        1       1    85   7875.0
# 25106          Santa Fe             3        2       0    98   8050.0
# 25108          Santa Fe             3        2       2   140  19250.0
# 25113          Coyoacán             3        1       2   150  52500.0
# 25114          Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 10         7000.0    2810.5
# ...

# %% [markdown]
# ### **Guardando los archivos**

# %%
df_nuevo.to_csv('inmuebles_ml.csv', index = False, sep = ';')

# %%
df1.to_csv('inmuebles_ml_filtro1.csv', index = False, sep = ';')
df2.to_csv('inmuebles_ml_filtro2.csv', index = False, sep = ';')
df3.to_csv('inmuebles_ml_filtro3.csv', index = False, sep = ';')

# %% [markdown]
# ## **Demandas de DEV**

# %% [markdown]
#  1. valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.

# %%
datos2 = pd.read_csv(url, sep=';')
datos2.shape
# Out:
# (25121, 9)

# %%
datos2['valor_mensual'] = datos2['Valor'] + datos2['Condominio']
datos2.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  valor_mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# 2. valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.

# %%
datos2['valor_anual'] = datos2['valor_mensual'] * 12 + datos2['Impuesto']
datos2.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  valor_mensual  valor_anual
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN

# %% [markdown]
# 3. Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %%
datos2['Descripcion'] = datos2['Tipo'] + ' en la colonia ' + datos2['Colonia'] + ' con ' + datos2['Habitaciones'].astype(str) + ' habitaciones y ' + datos2['Garages'].astype(str) + 'Plazas de estacionamiento'

# %%
datos2.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  valor_mensual  valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion
# ...

# %%
datos2.iloc[34].Descripcion
# Out:
# 'Departamento en la colonia San Pedro de los Pinos con 2 habitaciones y 2Plazas de estacionamiento'

# %% [markdown]
# 4. Tiene_suite: Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad.

# %%
datos2['Tiene_suite'] = datos2['Suites'].apply(lambda x: 'Si' if x > 0 else 'No')

# %%
datos2.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  valor_mensual  valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion Tiene_suite
# ...

# %%
datos.to_csv('/content/inmuebles_dev.csv', index = False, sep = ';')

# %% [markdown]
# # **Desafío Clase**

# %%
import pandas as pd

url2 = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

datos_nv = pd.read_csv(url2, sep=',')

# %%
datos_nv.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
datos_nv.tail(5)
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %%
datos_nv.shape
# Out:
# (18, 4)

# %%
datos_nv.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
datos_nv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
datos_nv['Nombre']
# Out:
# 0      Alberto
# 1          Ana
# 2       Camila
# 3        David
# 4        Brian
# 5        Bruna
# 6      Daniela
# 7       Carlos
# 8       Alicia
# 9       Victor
# 10      Danilo
# 11     Ignacio
# 12    Stephany
# 13      Miriam
# 14       Pablo
# 15      Milena
# 16       Lucas
# 17       Nadia
# Name: Nombre, dtype: object

# %%
datos_nv[['Nombre','Nota']]
# Out:
#       Nombre  Nota
# 0    Alberto   7.5
# 1        Ana   NaN
# 2     Camila   2.5
# 3      David   5.0
# 4      Brian  10.0
# 5      Bruna   NaN
# 6    Daniela   7.0
# 7     Carlos   6.0
# 8     Alicia   5.6
# 9     Victor   NaN
# 10    Danilo   NaN
# 11   Ignacio   4.5
# 12  Stephany  10.0
# 13    Miriam   9.0
# 14     Pablo   NaN
# 15    Milena   7.0
# 16     Lucas   NaN
# 17     Nadia   8.0

# %%
datos_nv.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %%
datos_nv.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.

# %%
datos_nv.isnull()
# Out:
#     Nombre   Edad   Nota  Aprobado
# 0    False  False  False     False
# 1    False  False   True     False
# 2    False  False  False     False
# 3    False  False  False     False
# 4    False  False  False     False
# 5    False  False   True     False
# 6    False  False  False     False
# 7    False  False  False     False
# 8    False  False  False     False
# 9    False  False   True     False
# 10   False  False   True     False
# 11   False  False  False     False
# 12   False  False  False     False
# 13   False  False  False     False
# 14   False  False   True     False
# 15   False  False  False     False
# 16   False  False   True     False
# 17   False  False  False     False

# %%
datos_nv.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
datos_nv= datos_nv.fillna(0)

# %% [markdown]
# Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.

# %%
exalumnos = datos_nv.query('Nombre == "Alicia" | Nombre == "Carlos"')

# %%
datos_nv.drop(exalumnos.index, axis=0, inplace=True)

# %% [markdown]
# Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.

# %%
# Normaliza y convierte a booleano
datos_nv['Aprobado'] = datos_nv['Aprobado'].astype(str).str.strip().str.lower().map({
    'true': True, 'false': False,
    'verdadero': True, 'falso': False,
    '1': True, '0': False
})

# %%
filter1 = datos_nv['Aprobado'] == True

# %%
datos_nv[filter1]
# Out:
#       Nombre  Edad  Nota  Aprobado
# 0    Alberto    20   7.5      True
# 4      Brian    21  10.0      True
# 6    Daniela    21   7.0      True
# 12  Stephany    26  10.0      True
# 13    Miriam    25   9.0      True
# 15    Milena    29   7.0      True
# 17     Nadia    34   8.0      True

# %%
df_aprobados = datos_nv[filter1]

# %%
df_aprobados.replace(7.0, 8.0)
# Out:
#       Nombre  Edad  Nota  Aprobado
# 0    Alberto    20   7.5      True
# 4      Brian    21  10.0      True
# 6    Daniela    21   8.0      True
# 12  Stephany    26  10.0      True
# 13    Miriam    25   9.0      True
# 15    Milena    29   8.0      True
# 17     Nadia    34   8.0      True

# %% [markdown]
# Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv"

# %%
df_aprobados.to_csv('alumnos_aprobados.csv')

# %% [markdown]
# Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.

# %%
datos_nv['Puntos_extras'] = datos_nv['Nota'].apply(lambda x: x*0.4 )

# %%
datos_nv['Puntos_extras']
# Out:
# 0     3.0
# 1     0.0
# 2     1.0
# 3     2.0
# 4     4.0
# 5     0.0
# 6     2.8
# 9     0.0
# 10    0.0
# 11    1.8
# 12    4.0
# 13    3.6
# 14    0.0
# 15    2.8
# 16    0.0
# 17    3.2
# Name: Puntos_extras, dtype: float64

# %% [markdown]
# 2. Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras

# %%
datos_nv['Notas_finales'] = datos_nv['Nota'] + datos_nv['Puntos_extras']

# %%
datos_nv['Notas_finales']
# Out:
# 0     10.5
# 1      0.0
# 2      3.5
# 3      7.0
# 4     14.0
# 5      0.0
# 6      9.8
# 9      0.0
# 10     0.0
# 11     6.3
# 12    14.0
# 13    12.6
# 14     0.0
# 15     9.8
# 16     0.0
# 17    11.2
# Name: Notas_finales, dtype: float64

# %% [markdown]
# 3. Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# * True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
#
# * False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).

# %%
datos_nv['Aprobado_final'] = datos_nv['Notas_finales'].apply(lambda x: True if x >= 7.0 else False)

# %%
datos_nv
# Out:
#       Nombre  Edad  Nota  Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.5      True            3.0           10.5
# 1        Ana    18   0.0     False            0.0            0.0
# 2     Camila    27   2.5     False            1.0            3.5
# 3      David    18   5.0     False            2.0            7.0
# 4      Brian    21  10.0      True            4.0           14.0
# 5      Bruna    23   0.0     False            0.0            0.0
# 6    Daniela    21   7.0      True            2.8            9.8
# 9     Victor    28   0.0     False            0.0            0.0
# 10    Danilo    21   0.0     False            0.0            0.0
# 11   Ignacio    24   4.5     False            1.8            6.3
# 12  Stephany    26  10.0      True            4.0           14.0
# 13    Miriam    25   9.0      True            3.6           12.6
# 14     Pablo    37   0.0     False            0.0            0.0
# ...

# %% [markdown]
# 4. Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.

# %%
datos_nv.query('Aprobado == False and Aprobado_final == True')
# Out:
#   Nombre  Edad  Nota  Aprobado  Puntos_extras  Notas_finales  Aprobado_final
# 3  David    18   5.0     False            2.0            7.0            True
